# %% [markdown]
# ## Trabalho Computacional 2 - Redes Complexas

# %% [markdown]
# ## Questão 1
#
# Considere o dataset **musae_facebook_edges.csv** e gere a rede G associada a este dataset.
#
# (a) Encontre o número de comunidades da rede retornada pela função do networkx **greedy_modularity_communities**.
#
# (b) Aplique a função do networkx **girvan_newman()** a rede G com o mesmo número de comunidades gerado no item (b).
#
# (c) Gere gráficos para visualizar os resultados dos itens (a) e (b).
#
# (d) Quais suas conclusões/observações de acordo com os experimentos.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_path = '../data/facebook/facebook_combined.txt'
G_social = nx.read_edgelist(data_path)

# %%
n = nx.number_of_nodes(G_social)
m = nx.number_of_edges(G_social)

print("#vertices =", n)
print("#arestas =", m)

print("rede eh conexa:", nx.is_connected(G_social))
# Out:
# #vertices = 4039
# #arestas = 88234
# rede eh conexa: True

# %%
#pos = nx.spring_layout(G_social, k=0.1)
#plt.rcParams.update({'figure.figsize': (20, 15)})
#nx.draw_networkx(
#    G_social,
#    pos=pos,
#    node_size=0,
#    edge_color="#444444",
#    alpha=0.05,
#    with_labels=False)
#plt.show()

# %%
#communities = sorted(nx.community.greedy_modularity_communities(G_social), key=len, reverse=True)
#len(communities)

# %%
#result = nx.community.girvan_newman(G_social)
#communities = next(result)
#len(communities)
#len(result)
#for i in result:
#    print(i)

# %%
G = nx.read_graphml('../data/football.graphml')

nx.draw(G,with_labels=True)
plt.show()

# %%
import itertools
k = 6
comp2 = nx.community.girvan_newman(G)
for communities in itertools.islice(comp2, k):
    print(tuple(sorted(c) for c in communities))
# Out:
# (['AirForce', 'Arizona', 'ArizonaState', 'ArkansasState', 'Baylor', 'BoiseState', 'BrighamYoung', 'California', 'Colorado', 'ColoradoState', 'FresnoState', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'IowaState', 'Kansas', 'KansasState', 'Michigan', 'MichiganState', 'Minnesota', 'Missouri', 'Nebraska', 'Nevada', 'NevadaLasVegas', 'NewMexico', 'NewMexicoState', 'NorthTexas', 'Northwestern', 'NotreDame', 'OhioState', 'Oklahoma', 'OklahomaState', 'Oregon', 'OregonState', 'PennState', 'Purdue', 'Rice', 'SanDiegoState', 'SanJoseState', 'SouthernCalifornia', 'SouthernMethodist', 'Stanford', 'Texas', 'TexasA&M', 'TexasChristian', 'TexasElPaso', 'TexasTech', 'Tulsa', 'UCLA', 'Utah', 'UtahState', 'Washington', 'WashingtonState', 'Wisconsin', 'Wyoming'], ['Akron', 'Alabama', 'AlabamaBirmingham', 'Arkansas', 'Army', 'Auburn', 'BallState', 'BostonCollege', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Cincinnati', 'Clemson', 'Connecticut', 'Duke', 'EastCarolina', 'EasternMichigan', 'Florida', 'FloridaState', 'Georgia', 'GeorgiaTech', 'Houston', 'Kent', 'Kentucky', 'LouisianaLafayette', 'LouisianaMonroe', 'LouisianaState', 'LouisianaTech', 'Louisville', 'Marshall', 'Maryland', 'Memphis', 'MiamiFlorida', 'MiamiOhio', 'MiddleTennesseeState', 'Mississippi', 'MississippiState', 'Navy', 'NorthCarolina', 'NorthCarolinaState', 'NorthernIllinois', 'Ohio', 'Pittsburgh', 'Rutgers', 'SouthCarolina', 'SouthernMississippi', 'Syracuse', 'Temple', 'Tennessee', 'Toledo', 'Tulane', 'Vanderbilt', 'Virginia', 'VirginiaTech', 'WakeForest', 'WestVirginia', 'WesternMichigan'])
# (['AirForce', 'Arizona', 'ArizonaState', 'ArkansasState', 'Baylor', 'BoiseState', 'BrighamYoung', 'California', 'Colorado', 'ColoradoState', 'FresnoState', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'IowaState', 'Kansas', 'KansasState', 'Michigan', 'MichiganState', 'Minnesota', 'Missouri', 'Nebraska', 'Nevada', 'NevadaLasVegas', 'NewMexico', 'NewMexicoState', 'NorthTexas', 'Northwestern', 'NotreDame', 'OhioState', 'Oklahoma', 'OklahomaState', 'Oregon', 'OregonState', 'PennState', 'Purdue', 'Rice', 'SanDiegoState', 'SanJoseState', 'SouthernCalifornia', 'SouthernMethodist', 'Stanford', 'Texas', 'TexasA&M', 'TexasChristian', 'TexasElPaso', 'TexasTech', 'Tulsa', 'UCLA', 'Utah', 'UtahState', 'Washington', 'WashingtonState', 'Wisconsin', 'Wyoming'], ['Alabama', 'AlabamaBirmingham', 'Arkansas', 'Army', 'Auburn', 'BostonCollege', 'Cincinnati', 'Clemson', 'Duke', 'EastCarolina', 'Florida', 'FloridaState', 'Georgia', 'GeorgiaTech', 'Houston', 'Kentucky', 'LouisianaLafayette', 'LouisianaMonroe', 'LouisianaState', 'LouisianaTech', 'Louisville', 'Maryland', 'Memphis', 'MiamiFlorida', 'MiddleTennesseeState', 'Mississippi', 'MississippiState', 'Navy', 'NorthCarolina', 'NorthCarolinaState', 'Pittsburgh', 'Rutgers', 'SouthCarolina', 'SouthernMississippi', 'Syracuse', 'Temple', 'Tennessee', 'Tulane', 'Vanderbilt', 'Virginia', 'VirginiaTech', 'WakeForest', 'WestVirginia'], ['Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'Marshall', 'MiamiOhio', 'NorthernIllinois', 'Ohio', 'Toledo', 'WesternMichigan'])
# (['AirForce', 'Arizona', 'ArizonaState', 'ArkansasState', 'Baylor', 'BoiseState', 'BrighamYoung', 'California', 'Colorado', 'ColoradoState', 'FresnoState', 'Hawaii', 'Idaho', 'IowaState', 'Kansas', 'KansasState', 'Missouri', 'Nebraska', 'Nevada', 'NevadaLasVegas', 'NewMexico', 'NewMexicoState', 'NorthTexas', 'NotreDame', 'Oklahoma', 'OklahomaState', 'Oregon', 'OregonState', 'Rice', 'SanDiegoState', 'SanJoseState', 'SouthernCalifornia', 'SouthernMethodist', 'Stanford', 'Texas', 'TexasA&M', 'TexasChristian', 'TexasElPaso', 'TexasTech', 'Tulsa', 'UCLA', 'Utah', 'UtahState', 'Washington', 'WashingtonState', 'Wyoming'], ['Alabama', 'AlabamaBirmingham', 'Arkansas', 'Army', 'Auburn', 'BostonCollege', 'Cincinnati', 'Clemson', 'Duke', 'EastCarolina', 'Florida', 'FloridaState', 'Georgia', 'GeorgiaTech', 'Houston', 'Kentucky', 'LouisianaLafayette', 'LouisianaMonroe', 'LouisianaState', 'LouisianaTech', 'Louisville', 'Maryland', 'Memphis', 'MiamiFlorida', 'MiddleTennesseeState', 'Mississippi', 'MississippiState', 'Navy', 'NorthCarolina', 'NorthCarolinaState', 'Pittsburgh', 'Rutgers', 'SouthCarolina', 'SouthernMississippi', 'Syracuse', 'Temple', 'Tennessee', 'Tulane', 'Vanderbilt', 'Virginia', 'VirginiaTech', 'WakeForest', 'WestVirginia'], ['Illinois', 'Indiana', 'Iowa', 'Michigan', 'MichiganState', 'Minnesota', 'Northwestern', 'OhioState', 'PennState', 'Purdue', 'Wisconsin'], ['Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'Marshall', 'MiamiOhio', 'NorthernIllinois', 'Ohio', 'Toledo', 'WesternMichigan'])
# (['AirForce', 'Arizona', 'ArizonaState', 'ArkansasState', 'Baylor', 'BoiseState', 'BrighamYoung', 'California', 'Colorado', 'ColoradoState', 'FresnoState', 'Hawaii', 'Idaho', 'IowaState', 'Kansas', 'KansasState', 'Missouri', 'Nebraska', 'Nevada', 'NevadaLasVegas', 'NewMexico', 'NewMexicoState', 'NorthTexas', 'NotreDame', 'Oklahoma', 'OklahomaState', 'Oregon', 'OregonState', 'Rice', 'SanDiegoState', 'SanJoseState', 'SouthernCalifornia', 'SouthernMethodist', 'Stanford', 'Texas', 'TexasA&M', 'TexasChristian', 'TexasElPaso', 'TexasTech', 'Tulsa', 'UCLA', 'Utah', 'UtahState', 'Washington', 'WashingtonState', 'Wyoming'], ['BostonCollege', 'Clemson', 'Duke', 'FloridaState', 'GeorgiaTech', 'Maryland', 'MiamiFlorida', 'Navy', 'NorthCarolina', 'NorthCarolinaState', 'Pittsburgh', 'Rutgers', 'Syracuse', 'Temple', 'Virginia', 'VirginiaTech', 'WakeForest', 'WestVirginia'], ['Illinois', 'Indiana', 'Iowa', 'Michigan', 'MichiganState', 'Minnesota', 'Northwestern', 'OhioState', 'PennState', 'Purdue', 'Wisconsin'], ['Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'Marshall', 'MiamiOhio', 'NorthernIllinois', 'Ohio', 'Toledo', 'WesternMichigan'], ['Alabama', 'AlabamaBirmingham', 'Arkansas', 'Army', 'Auburn', 'Cincinnati', 'EastCarolina', 'Florida', 'Georgia', 'Houston', 'Kentucky', 'LouisianaLafayette', 'LouisianaMonroe', 'LouisianaState', 'LouisianaTech', 'Louisville', 'Memphis', 'MiddleTennesseeState', 'Mississippi', 'MississippiState', 'SouthCarolina', 'SouthernMississippi', 'Tennessee', 'Tulane', 'Vanderbilt'])
# (['AirForce', 'Arizona', 'ArizonaState', 'ArkansasState', 'BoiseState', 'BrighamYoung', 'California', 'ColoradoState', 'FresnoState', 'Hawaii', 'Idaho', 'Nevada', 'NevadaLasVegas', 'NewMexico', 'NewMexicoState', 'NorthTexas', 'Oregon', 'OregonState', 'Rice', 'SanDiegoState', 'SanJoseState', 'SouthernCalifornia', 'SouthernMethodist', 'Stanford', 'TexasChristian', 'TexasElPaso', 'Tulsa', 'UCLA', 'Utah', 'UtahState', 'Washington', 'WashingtonState', 'Wyoming'], ['BostonCollege', 'Clemson', 'Duke', 'FloridaState', 'GeorgiaTech', 'Maryland', 'MiamiFlorida', 'Navy', 'NorthCarolina', 'NorthCarolinaState', 'Pittsburgh', 'Rutgers', 'Syracuse', 'Temple', 'Virginia', 'VirginiaTech', 'WakeForest', 'WestVirginia'], ['Illinois', 'Indiana', 'Iowa', 'Michigan', 'MichiganState', 'Minnesota', 'Northwestern', 'OhioState', 'PennState', 'Purdue', 'Wisconsin'], ['Baylor', 'Colorado', 'IowaState', 'Kansas', 'KansasState', 'Missouri', 'Nebraska', 'NotreDame', 'Oklahoma', 'OklahomaState', 'Texas', 'TexasA&M', 'TexasTech'], ['Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'Marshall', 'MiamiOhio', 'NorthernIllinois', 'Ohio', 'Toledo', 'WesternMichigan'], ['Alabama', 'AlabamaBirmingham', 'Arkansas', 'Army', 'Auburn', 'Cincinnati', 'EastCarolina', 'Florida', 'Georgia', 'Houston', 'Kentucky', 'LouisianaLafayette', 'LouisianaMonroe', 'LouisianaState', 'LouisianaTech', 'Louisville', 'Memphis', 'MiddleTennesseeState', 'Mississippi', 'MississippiState', 'SouthCarolina', 'SouthernMississippi', 'Tennessee', 'Tulane', 'Vanderbilt'])
# (['AirForce', 'Arizona', 'ArizonaState', 'ArkansasState', 'BoiseState', 'BrighamYoung', 'California', 'ColoradoState', 'Idaho', 'NevadaLasVegas', 'NewMexico', 'NewMexicoState', 'NorthTexas', 'Oregon', 'OregonState', 'SanDiegoState', 'SouthernCalifornia', 'Stanford', 'UCLA', 'Utah', 'UtahState', 'Washington', 'WashingtonState', 'Wyoming'], ['BostonCollege', 'Clemson', 'Duke', 'FloridaState', 'GeorgiaTech', 'Maryland', 'MiamiFlorida', 'Navy', 'NorthCarolina', 'NorthCarolinaState', 'Pittsburgh', 'Rutgers', 'Syracuse', 'Temple', 'Virginia', 'VirginiaTech', 'WakeForest', 'WestVirginia'], ['Illinois', 'Indiana', 'Iowa', 'Michigan', 'MichiganState', 'Minnesota', 'Northwestern', 'OhioState', 'PennState', 'Purdue', 'Wisconsin'], ['Baylor', 'Colorado', 'IowaState', 'Kansas', 'KansasState', 'Missouri', 'Nebraska', 'NotreDame', 'Oklahoma', 'OklahomaState', 'Texas', 'TexasA&M', 'TexasTech'], ['Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'Marshall', 'MiamiOhio', 'NorthernIllinois', 'Ohio', 'Toledo', 'WesternMichigan'], ['Alabama', 'AlabamaBirmingham', 'Arkansas', 'Army', 'Auburn', 'Cincinnati', 'EastCarolina', 'Florida', 'Georgia', 'Houston', 'Kentucky', 'LouisianaLafayette', 'LouisianaMonroe', 'LouisianaState', 'LouisianaTech', 'Louisville', 'Memphis', 'MiddleTennesseeState', 'Mississippi', 'MississippiState', 'SouthCarolina', 'SouthernMississippi', 'Tennessee', 'Tulane', 'Vanderbilt'], ['FresnoState', 'Hawaii', 'Nevada', 'Rice', 'SanJoseState', 'SouthernMethodist', 'TexasChristian', 'TexasElPaso', 'Tulsa'])

# %%
comp1 = sorted(nx.community.greedy_modularity_communities(G), key=len, reverse=True)
len(comp1)
print(comp1)
# Out:
# [frozenset({'Kentucky', 'Army', 'Memphis', 'Tulane', 'LouisianaMonroe', 'EastCarolina', 'Georgia', 'Louisville', 'MississippiState', 'AlabamaBirmingham', 'Florida', 'Alabama', 'Mississippi', 'Cincinnati', 'SouthernMississippi', 'CentralFlorida', 'LouisianaLafayette', 'LouisianaState', 'Arkansas', 'Tennessee', 'MiddleTennesseeState', 'Houston', 'Connecticut', 'SouthCarolina', 'Vanderbilt', 'Auburn', 'LouisianaTech'}), frozenset({'SouthernCalifornia', 'Oregon', 'Hawaii', 'NevadaLasVegas', 'UCLA', 'Tulsa', 'SanJoseState', 'FresnoState', 'BrighamYoung', 'Wyoming', 'Arizona', 'Utah', 'OregonState', 'ColoradoState', 'WashingtonState', 'Stanford', 'SouthernMethodist', 'California', 'Rice', 'AirForce', 'SanDiegoState', 'TexasChristian', 'Washington', 'ArizonaState', 'Nevada'}), frozenset({'NewMexicoState', 'Kansas', 'Baylor', 'TexasElPaso', 'TexasTech', 'Nebraska', 'Idaho', 'Missouri', 'KansasState', 'IowaState', 'Texas', 'OklahomaState', 'Oklahoma', 'NorthTexas', 'Colorado', 'NewMexico', 'TexasA&M', 'UtahState', 'Iowa', 'ArkansasState', 'BoiseState'}), frozenset({'Rutgers', 'Virginia', 'NorthCarolinaState', 'Maryland', 'Navy', 'Temple', 'VirginiaTech', 'Pittsburgh', 'WakeForest', 'NorthCarolina', 'Syracuse', 'MiamiFlorida', 'WestVirginia', 'Duke', 'GeorgiaTech', 'BostonCollege', 'NotreDame', 'Clemson', 'FloridaState'}), frozenset({'Akron', 'Buffalo', 'CentralMichigan', 'BowlingGreenState', 'NorthernIllinois', 'Marshall', 'MiamiOhio', 'WesternMichigan', 'Ohio', 'BallState', 'Toledo', 'EasternMichigan', 'Kent'}), frozenset({'Minnesota', 'PennState', 'Illinois', 'MichiganState', 'Indiana', 'OhioState', 'Wisconsin', 'Michigan', 'Northwestern', 'Purdue'})]

# %%
comp1 == comp2
# Out:
# False

# %% [markdown]
# ## Questão 2
#
# Considere a função do networkx **erdos_renyi_graph()**
#
# (a) gere redes de tamanho 1000 e probabilidade para criação de arestas igual a 0.2, 0.3 e 0.5.
#
# (b) Calcule para cada rede: centralidade de grau, valor médio do comprimento dos caminhos geodésicos, densidade, coeficiente de agrupamento e o diâmetro.
#
# (c) Quais suas conclusões/observações de acordo com os experimentos.

# %% [markdown]
# ## Questão 3
#
# Considere a função do networkx **barabasi_albert_graph()**.
#
# (a) gere redes de tamanho 1000 e número de ligações igual a 5, 10, 25 e 50.
#
# (b) Calcule para cada rede: centralidade de grau, valor médio do comprimento dos caminhos geodésicos, densidade, coeficiente de agrupamento e diâmetro.
#
# (c) Quais suas conclusões/observações de acordo com os experimentos.

# %% [markdown]
# ## Questão 4
#
# Considere a função do networkx **barabasi_albert_graph()**.
#
# (a) gere uma rede com 1000 nós e 7 ligações por vértice.
#
# (b) Implemente o modelo SI, onde $5\%$ dos nós estão inicialmente infectados, probabilidade de infecção igual a 0,05 e o número total de 200 simulações.
#
# (c) Crie um gráfico mostrando o percentual de infectados ao longo do tempo(200).
#
# (d) Quais suas conclusões/observações de acordo como os experimentos.

# %% [markdown]
# ## Questão 5
#
# Considere a função do networkx **barabasi_albert_graph()**.
#
# (a) gere uma rede com 1000 nós e 7 ligações por vértice.
#
# (b) Implemente o modelo SIR, onde $5\%$ dos nós estão inicialmente infectados, probabilidade de infecção igual a 0.05 e o número total de 200 simulações.
#
# (c) Crie um gráfico mostrando o percentual de infectados e o percentual de recuperados ao longo do tempo(200).
#
# (d) Quais suas conclusões/observações de acordo como os experimentos.
